# %% [markdown]
# ## TP_Projet

# %%
import re

data = open("CISI.ALLnettoye","r").readlines()
data=[i[:len(i)-1] for i in data] #Enleve le '\n'
documents=[]
titles=[]
#data

#for ind in range(len(data)):
#    if ".I " in data[ind]:
#        titles.append(data[ind+1])
#titles

collection =[]
for line in range(46): # Remplacer 50 par le nb de lignes au total (c'est a dire: len(data))
    if data[line].split()[0]==".I":
        doc=[]
        collection.append(doc)
    else:
        doc.append(data[line])
collection
# Out:
# [['18 Editions of the Dewey Decimal Classifications',
#   '   The present study is a history of the DEWEY Decimal',
#   'Classification.  The first edition of the DDC was published',
#   'in 1876, the eighteenth edition in 1971, and future editions',
#   "will continue to appear as needed.  In spite of the DDC's",
#   'long and healthy life, however, its full story has never',
#   'been told.  There have been biographies of Dewey',
#   'that briefly describe his system, but this is the first',
#   'attempt to provide a detailed history of the work that',
#   'more than any other has spurred the growth of',
#   'librarianship in this country and abroad.'],
#  ['Use Made of Technical Libraries',
#   'This report is an analysis of 6300 acts of use',
#   'in 104 technical libraries in the United Kingdom.',
#   'Library use is only one aspect of the wider pattern of',
#   'information use.  Information transfer in libraries is',
#   'restricted to the use of documents.  It takes no',
# ...

# %%
titles=[]
content=[]
for doc in collection:
    titles.append(doc[0])
    content.append(doc[1:])
titles
content
# Out:
# [['   The present study is a history of the DEWEY Decimal',
#   'Classification.  The first edition of the DDC was published',
#   'in 1876, the eighteenth edition in 1971, and future editions',
#   "will continue to appear as needed.  In spite of the DDC's",
#   'long and healthy life, however, its full story has never',
#   'been told.  There have been biographies of Dewey',
#   'that briefly describe his system, but this is the first',
#   'attempt to provide a detailed history of the work that',
#   'more than any other has spurred the growth of',
#   'librarianship in this country and abroad.'],
#  ['This report is an analysis of 6300 acts of use',
#   'in 104 technical libraries in the United Kingdom.',
#   'Library use is only one aspect of the wider pattern of',
#   'information use.  Information transfer in libraries is',
#   'restricted to the use of documents.  It takes no',
#   'account of documents used outside the library, still',
# ...

# %%
from nltk.tokenize import word_tokenize

#[word_tokenize(line) for line in content]

d=[[word_tokenize(line) for line in content[i]] for i in range(len(content))]

d[0][0]
# Out:
# ['The',
#  'present',
#  'study',
#  'is',
#  'a',
#  'history',
#  'of',
#  'the',
#  'DEWEY',
#  'Decimal']

# %%
occurence = dict()
for doc in d:
    for line in doc:
        for word in line:
            occurence[word]=0
for doc in d:
    for line in doc:
        for word in line:
            occurence[word] += line.count(word)
occurence
# Out:
# {"'s": 2,
#  ',': 33,
#  '-': 2,
#  '.': 15,
#  '104': 1,
#  '1876': 1,
#  '1971': 1,
#  '6300': 1,
#  'An': 1,
#  'As': 1,
#  'Bibliographic': 1,
#  'Bibliographical': 1,
#  'Classification': 1,
#  'Control': 1,
#  'DDC': 2,
#  'DEWEY': 1,
#  'Decimal': 1,
#  'Dewey': 1,
#  'Essay': 1,
#  'Even': 1,
#  'In': 1,
#  'Information': 1,
#  'It': 1,
#  'Kingdom': 1,
#  'Library': 1,
#  'Taking': 1,
#  'The': 4,
#  'There': 2,
#  'This': 1,
#  'United': 1,
#  'a': 13,
#  'abroad': 1,
#  'account': 1,
#  'acts': 2,
#  'all': 1,
#  'along': 1,
#  'also': 1,
#  'an': 1,
#  'analysis': 1,
#  'and': 19,
#  'any': 2,
#  'appear': 1,
#  'are': 2,
#  'as': 5,
#  'aspect': 1,
#  'at': 1,
#  'attempt': 1,
#  'been': 4,
#  'between': 1,
#  'bibliographical': 2,
#  'biographies': 1,
#  'briefly': 1,
#  'but': 1,
#  'can': 1,
#  'certain': 1,
#  'channel': 1,
#  'claims': 1,
#  'colleagues': 1,
#  'collections': 1,
#  'contact': 1,
#  'contain': 1,
#  'contained': 1,
#  'continue': 1,
#  'control': 6,
# ...

# %%
list(occurence.keys())
# Out:
# ['system',
#  'this',
#  'United',
#  'future',
#  'also',
#  'proportion',
#  'library',
#  'recorded',
#  'growth',
#  'Kingdom',
#  'biographies',
#  'account',
#  'contact',
#  'much',
#  'This',
#  'certain',
#  'needed',
#  'used',
#  '-',
#  'less',
#  'that',
#  'contained',
#  "'s",
#  'is',
#  'published',
#  'pattern',
#  'regular',
#  'sense',
#  'its',
#  'writings',
#  'describe',
#  'libraries',
#  'handbooks',
#  'first',
#  'rarely',
#  '104',
#  'receive',
#  'Taking',
#  'edition',
#  'person',
#  'there',
#  'technology',
#  'science',
#  'we',
#  'was',
#  'from',
#  'rather',
#  'appear',
#  'situations',
#  'all',
#  'As',
#  'information',
#  'present',
#  'organizations',
#  'obtain',
#  'DEWEY',
#  'long',
#  'current',
#  'itself',
#  'detailed',
#  'to',
#  'provide',
#  'full',
#  'transferred',
#  'can',
#  'will',
#  'inevitably',
#  'and',
#  'technical',
#  'report',
#  'on',
#  'Information',
#  'life',
#  'Even',
#  'discuss',
#  '6300',
# ...

# %%
def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict

computeTF(occurence,list(occurence.keys()))
# Out:
# {"'s": 0.010362694300518135,
#  ',': 0.17098445595854922,
#  '-': 0.010362694300518135,
#  '.': 0.07772020725388601,
#  '104': 0.0051813471502590676,
#  '1876': 0.0051813471502590676,
#  '1971': 0.0051813471502590676,
#  '6300': 0.0051813471502590676,
#  'An': 0.0051813471502590676,
#  'As': 0.0051813471502590676,
#  'Bibliographic': 0.0051813471502590676,
#  'Bibliographical': 0.0051813471502590676,
#  'Classification': 0.0051813471502590676,
#  'Control': 0.0051813471502590676,
#  'DDC': 0.010362694300518135,
#  'DEWEY': 0.0051813471502590676,
#  'Decimal': 0.0051813471502590676,
#  'Dewey': 0.0051813471502590676,
#  'Essay': 0.0051813471502590676,
#  'Even': 0.0051813471502590676,
#  'In': 0.0051813471502590676,
#  'Information': 0.0051813471502590676,
#  'It': 0.0051813471502590676,
#  'Kingdom': 0.0051813471502590676,
#  'Library': 0.0051813471502590676,
#  'Taking': 0.0051813471502590676,
#  'The': 0.02072538860103627,
#  'There': 0.010362694300518135,
# ...

# %%
def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict
computeIDF(collection)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-e79762e96bce> in <module>
#      12         idfDict[word] = math.log(N / float(val))
#      13     return idfDict
# ---> 14 computeIDF(collection)
#
# <ipython-input-85-e79762e96bce> in computeIDF(documents)
#       3     N = len(documents)
#       4
# ----> 5     idfDict = dict.fromkeys(documents[0].keys(), 0)
#       6     for document in documents:
#       7         for word, val in document.items():
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf
